# %% [markdown]
# <a href="https://colab.research.google.com/github/Hello-Hos/Pycaret-for-regression-with-results/blob/main/01_Pycaret_for_regression_with_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null #silent installation
print("pycaret installed successfully")
from pycaret.datasets import get_data
data= get_data('index')
# Out:
# pycaret installed successfully
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
bostonDataset =get_data("boston") #SN is 46
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
type("boston")
# Out:
# str

# %%
type(bostonDataset)
# Out:
# pandas.core.frame.DataFrame

# %%
bostonDataset.shape
# Out:
# (506, 14)

# %%
from pycaret.regression import *
s= setup(data = bostonDataset,target='medv')
# Out:
# <style type="text/css">
# #T_534b0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_534b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_534b0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_534b0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_534b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_534b0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_534b0_row0_col1" class="data row0 col1" >6363</td>
#     </tr>
#     <tr>
#       <th id="T_534b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_534b0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_534b0_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_534b0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm=compare_models()
# Out:
# <style type="text/css">
# #T_84dff th {
#   text-align: left;
# }
# ...

# %%
insuranceDataset =get_data("insurance")
setup(data = insuranceDataset , target='charges')
cm= compare_models()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_95d7b_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_95d7b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95d7b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_95d7b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95d7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95d7b_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %%
# !pip install summarytools
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for summarytools: filename=summarytools-0.2.3-py3-none-any.whl size=8573 sha256=f5e9d40539abf90c4eb636f8ec62bdbe4acf5cc9617d2aa5b086341112e1a7e3
#   Stored in directory: /root/.cache/pip/wheels/d5/8a/5d/008e2127a7f9dd64d066f16e5ea268fa52823dc929c982d6f1
# Successfully built summarytools
# ...

# %%
from summarytools import dfSummary
dfSummary(insuranceDataset)
# Out:
# <style type="text/css">
# #T_82a11 thead>tr>th {
#   text-align: left;
# }
# #T_82a11_row0_col0, #T_82a11_row1_col0, #T_82a11_row2_col0, #T_82a11_row3_col0, #T_82a11_row4_col0, #T_82a11_row5_col0, #T_82a11_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_82a11_row0_col1, #T_82a11_row1_col1, #T_82a11_row2_col1, #T_82a11_row3_col1, #T_82a11_row4_col1, #T_82a11_row5_col1, #T_82a11_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_82a11_row0_col2, #T_82a11_row1_col2, #T_82a11_row2_col2, #T_82a11_row3_col2, #T_82a11_row4_col2, #T_82a11_row5_col2, #T_82a11_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# ...

# %%
bostonDataset.to_csv("bostonDataset.csv" , index= False)
from google.colab import files
files.download('bostonDataset.csv')

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1d39ece9-96fc-4f37-ba5f-548fed7b6739" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d39ece9-96fc-4f37-ba5f-548fed7b6739">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
myDataset =pd.read_csv('bostonDataset (1).csv')
myDataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
setup(data =myDataset, target='medv')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_5d811_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5d811" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d811_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5d811_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d811_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d811_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5d811_row0_col1" class="data row0 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_5d811_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d811_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5d811_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_5d811_level0_row2" class="row_heading level0 row2" >2</th>
# ...
